# %% [markdown]
# # Polynomial Regression
# #### Polynomial Regression is a type of regression where:
# #### The relationship between input and output is modeled as an nth-degree polynomial.
#
# #### -> Even though it models non-linear relationships, it is still: A linear model in terms of parameters.
#
# ---
#
# ## Why Do We Need It?
# #### Linear Regression assumes:
# #### ``` 𝑦 = 𝑏 + 𝑚𝑋```
# #### But many real-world relationships are non-linear:
# <ul>
#     <li>Growth curves</li>
#     <li>Sales trends</li>
#     <li>Temperature changes</li>
#     <li>Economic indicators</li>
# </ul>
#
# #### So we extend model to:
# #### ```y = b + w1.​X + w2​.X^2 + w3.​X^3 + ... + wn.​X^n```
#
# ---
#
# ## Example
# #### Suppose relationship looks like a curve:
# ```
#      *
#    *   *
#  *       *
#
# ```
# #### A straight line won’t fit well.
# #### A quadratic function:
# #### ```y = b + w1.​X + w2.​X^2```
# #### can capture curvature.
#
# ### Mathematical Form
# #### For degree 2:
# #### ```y = b + w1.​X + w2.​X^2```
#
# #### For degree 3:
# #### ``` y = b + w1.​X + w2.​X^2 + w3.​X^3```
#
# ---
#
# ## Important Concept
#
# #### Although it looks non-linear in X,
# #### It is linear in parameters:
# #### ``` y = w0 + w1.​z1​ + w2.​z2​```
# #### Where:
# <ul>
#     <li>z1 = X</li>
#     <li>Z2 = X^2</li>
# </ul>
#
# #### So we can still use:
# <ul>
#     <li>✔ Normal Equation</li>
#     <li>✔ Gradient Descent</li>
# </ul>
#
# ---
#
# ## Geometrical Intuition
# #### Degree 1 → straight line <br/>
# #### Degree 2 → parabola <br/>
# #### Degree 3 → S-curve <br/>
# #### Higher degree → more flexible curve
#
# ---
#
# ## Underfitting vs Overfitting
# ### Low degree (1):
# <ul>
#     <li>High bias</li>
#     <li>Underfitting</li>
# </ul>
#
# ### High degree (10+):
# <ul>
#     <li>High variance</li>
#     <li>Overfitting</li>
# </ul>
#
# #### We must choose degree carefully.
#
# ---
